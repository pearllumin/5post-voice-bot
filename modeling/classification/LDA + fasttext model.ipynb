# %%
from google.colab import drive
drive.mount('/content/drive')
# !pip install fasttext
import pandas as pd
import fasttext
from sklearn.model_selection import train_test_split
# Out:
# Mounted at /content/drive
# Collecting fasttext
#   Downloading fasttext-0.9.2.tar.gz (68 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.8/68.8 kB 2.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting pybind11>=2.2 (from fasttext)
#   Using cached pybind11-2.12.0-py3-none-any.whl (234 kB)
# Requirement already satisfied: setuptools>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from fasttext) (67.7.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from fasttext) (1.25.2)
# Building wheels for collected packages: fasttext
#   Building wheel for fasttext (setup.py) ... done
#   Created wheel for fasttext: filename=fasttext-0.9.2-cp310-cp310-linux_x86_64.whl size=4227137 sha256=a162685d4a8e41bb04fb7bd44b207f04bd4249b8abaf3cbfade9aad4576d8faf
#   Stored in directory: /root/.cache/pip/wheels/a5/13/75/f811c84a8ab36eedbaef977a6a58a98990e8e0f1967f98f394
# Successfully built fasttext
# Installing collected packages: pybind11, fasttext
# Successfully installed fasttext-0.9.2 pybind11-2.12.0

# %% [markdown]
# # Считываем данные и преобразуем под формат fasttext

# %%
# данные полученные из ноутбука "X5 tematic model LDA"
df = pd.read_csv("/content/drive/MyDrive/x5_data.csv")
df_kmeans =
print(df.shape)
df.head(3)
# Out:
# (1699223, 2)
#                               text                 class
# 0             узнать статус заказа  узнать_статус_заказа
# 1             не работает постамат    проблемы_с_ячейкой
# 2  живой оператор можете соединить    проблемы_с_ячейкой

# %%
# приводим классы к формату модели
df['class'] = '__label__' + df['class'].astype(str)
df.head(5)

df['category_description'] = df['class'] + ' ' + df['text']
df.head(3)
# Out:
#                               text                          class  \
# 0             узнать статус заказа  __label__узнать_статус_заказа
# 1             не работает постамат    __label__проблемы_с_ячейкой
# 2  живой оператор можете соединить    __label__проблемы_с_ячейкой
#
#                                 category_description
# 0  __label__узнать_статус_заказа узнать статус за...
# 1   __label__проблемы_с_ячейкой не работает постамат
# 2  __label__проблемы_с_ячейкой живой оператор мож...

# %%
# делим данные на обучающую и тестовую выборки
train, test = train_test_split(df, test_size=0.2)

# %%
train.shape, test.shape
# Out:
# ((1359378, 3), (339845, 3))

# %%
train.to_csv("/content/drive/MyDrive/x5_data_train", columns=["category_description"], index=False, header=False)
test.to_csv("/content/drive/MyDrive/x5_data_test", columns=["category_description"], index=False, header=False)

# %% [markdown]
# # Обучаем модель

# %%
import fasttext

model = fasttext.train_supervised(input="/content/drive/MyDrive/x5_data_train")

# прверяем качество модели (precision, recall)
model.test("/content/drive/MyDrive/x5_data_test")
# Out:
# (339845, 0.9503626653327252, 0.9503626653327252)

# %% [markdown]
# # Делаем предсказание

# %%
model.predict("где мой заказ?")
# Out:
# (('__label__узнать_статус_заказа',), array([0.79343069]))
